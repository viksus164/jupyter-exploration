# %% [markdown]
# # My First Markdown Cell in Jupyter
#
# I am learning how to use Markdown in Google Colab.
#
# `print("Hello")` is an example of code.

# %%
print("Hello, World! I am learning to use code cells in Google Collab.")
# Out:
# Hello, World! I am learning to use code cells in Google Collab.
